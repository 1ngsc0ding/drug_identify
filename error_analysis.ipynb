# %%
import os, shutil
def rm_mkdir(folder):
    if os.path.exists(folder):
        shutil.rmtree(folder)
        os.makedirs(folder)
    else:
        os.makedirs(folder)

# %%
import os
from tqdm.notebook import tqdm
os.getcwd()
# Out:
# '/media/numing/data/drug_identify/dataprep'

# %%
I:\drug_identify\yolov9\tvt\val\labels

# %%
labels_source2 = '../yolov9/tvt/val/labels'
ls_labels2 = os.listdir(labels_source2)

# %%
ls_labels2
# Out:
# ['RXBASE-120_00002-3239-30_NLMIMAGE10_3F1E1F80.txt',
#  'RXBASE-120_00002-3270-30_NLMIMAGE10_A91354EA.txt',
#  'RXBASE-120_00002-4772-90_NLMIMAGE10_8C16C656.txt',
#  'RXBASE-120_00002-5123-30_NLMIMAGE10_E848F457.txt',
#  'RXBASE-120_00004-0800-85_NLMIMAGE10_491E24C1.txt',
#  'RXBASE-120_00006-0080-61_NLMIMAGE10_3A3E1D10.txt',
#  'RXBASE-120_00006-0227-61_NLMIMAGE10_A11DD0FE.txt',
#  'RXBASE-120_00006-0960-54_NLMIMAGE10_C31361AB.txt',
#  'RXBASE-120_00007-3151-13_NLMIMAGE10_A018D026.txt',
#  'RXBASE-120_00007-3650-22_NLMIMAGE10_4C192669.txt',
#  'RXBASE-120_00007-4885-61_NLMIMAGE10_1F190FB8.txt',
#  'RXBASE-120_00007-4888-13_NLMIMAGE10_FE18FF67.txt',
#  'RXBASE-120_00007-4895-20_NLMIMAGE10_D218E947.txt',
#  'RXBASE-120_00008-0606-01_NLMIMAGE10_BF085FE2.txt',
#  'RXBASE-120_00008-1222-30_NLMIMAGE10_563EAB05.txt',
#  'RXBASE-120_00009-5135-02_NLMIMAGE10_D6506B63.txt',
#  'RXBASE-120_00024-4200-10_NLMIMAGE10_27201390.txt',
#  'RXBASE-120_00025-1411-60_NLMIMAGE10_C812E407.txt',
# ...

# %%
a
# Out:
# 'RXBASE-120_00002-3239-30_NLMIMAGE10_3F1E1F80.txt'

# %%
path
# Out:
# '../yolov9/tvt/val/labels/RXBASE-120_00002-3239-30_NLMIMAGE10_3F1E1F80.txt'

# %%
# ทดสอบเปลี่ยน class ในไฟล์ labels
ls_txt2 = []
a = ls_labels2[0]
path = os.path.join(labels_source2,a).replace('\\','/')
with open(path) as txt:
    txt = txt.read().splitlines()
    # with open('/content/drive/MyDrive/datasets/drug_c3pi/4train/pseudo_lables/'+a, 'w') as dst_file:
    #     for line in txt:
    #         cl, x, y, w, h = [i for i in line.split(' ')]
    #         dst_file.writelines(' '.join(['abc', x, y, w, h])+'\n')
    for line in txt:
        cl, x, y, w, h = [i for i in line.split(' ')]
        ls_txt2.append([' '.join([a, cl, x, y, w, h])])


ls_txt2
# Out:
# [['RXBASE-120_00002-3239-30_NLMIMAGE10_3F1E1F80.txt 1535 0.516667 0.234375 0.966667 0.427083'],
#  ['RXBASE-120_00002-3239-30_NLMIMAGE10_3F1E1F80.txt 1535 0.516667 0.713542 0.966667 0.427083']]

# %%
# ทดสอบเปลี่ยน class ในไฟล์ labels ไล่ทีละไฟล์
ls_txt2 = []
for a in tqdm(ls_labels2):
    path = os.path.join(labels_source2,a).replace('\\','/')
    with open(path) as txt:
        txt = txt.read().splitlines()
        # with open('/content/drive/MyDrive/datasets/drug_c3pi/4train/pseudo_lables/'+a, 'w') as dst_file:
        #     for line in txt:
        #         cl, x, y, w, h = [i for i in line.split(' ')]
        #         dst_file.writelines(' '.join(['abc', x, y, w, h])+'\n')
        for line in txt:
            cl, x, y, w, h = [i for i in line.split(' ')]
            ls_txt2.append([a, cl, x, y, w, h])


ls_txt2
# Out:
#   0%|          | 0/4750 [00:00<?, ?it/s]
# [['RXBASE-120_00002-3239-30_NLMIMAGE10_3F1E1F80.txt',
#   '1535',
#   '0.516667',
#   '0.234375',
#   '0.966667',
#   '0.427083'],
#  ['RXBASE-120_00002-3239-30_NLMIMAGE10_3F1E1F80.txt',
#   '1535',
#   '0.516667',
#   '0.713542',
#   '0.966667',
#   '0.427083'],
#  ['RXBASE-120_00002-3270-30_NLMIMAGE10_A91354EA.txt',
#   '1637',
#   '0.5125',
#   '0.234375',
#   '0.975',
#   '0.427083'],
#  ['RXBASE-120_00002-3270-30_NLMIMAGE10_A91354EA.txt',
#   '1637',
#   '0.5125',
#   '0.713542',
#   '0.975',
#   '0.427083'],
#  ['RXBASE-120_00002-4772-90_NLMIMAGE10_8C16C656.txt',
#   '1812',
#   '0.2625',
#   '0.463542',
#   '0.491667',
#   '0.59375'],
#  ['RXBASE-120_00002-4772-90_NLMIMAGE10_8C16C656.txt',
#   '1812',
#   '0.766667',
#   '0.463542',
#   '0.466667',
#   '0.59375'],
#  ['RXBASE-120_00002-5123-30_NLMIMAGE10_E848F457.txt',
#   '1820',
#   '0.520833',
#   '0.234375',
#   '0.741667',
#   '0.447917'],
# ...

# %%
import pandas as pd
df_val = pd.DataFrame(ls_txt2, columns =['a','cl','x','y','w','h'])

# %%
df_val
# Out:
#                                                      a    cl         x  \
# 0     RXBASE-120_00002-3239-30_NLMIMAGE10_3F1E1F80.txt  1535  0.516667
# 1     RXBASE-120_00002-3239-30_NLMIMAGE10_3F1E1F80.txt  1535  0.516667
# 2     RXBASE-120_00002-3270-30_NLMIMAGE10_A91354EA.txt  1637    0.5125
# 3     RXBASE-120_00002-3270-30_NLMIMAGE10_A91354EA.txt  1637    0.5125
# 4     RXBASE-120_00002-4772-90_NLMIMAGE10_8C16C656.txt  1812    0.2625
# ...                                                ...   ...       ...
# 9495  RXBASE-600_68462-0331-90_NLMIMAGE10_F43E7A43.txt  1269  0.764167
# 9496  RXBASE-600_68462-0720-84_NLMIMAGE10_F44FFA2F.txt  2064  0.276667
# 9497  RXBASE-600_68462-0720-84_NLMIMAGE10_F44FFA2F.txt  2064  0.761667
# 9498  RXBASE-600_68682-0409-10_NLMIMAGE10_6D39B6CD.txt   533  0.520833
# 9499  RXBASE-600_68682-0409-10_NLMIMAGE10_6D39B6CD.txt   533    0.5225
#
#              y         w         h
# 0     0.234375  0.966667  0.427083
# 1     0.713542  0.966667  0.427083
# ...

# %%
import os
labels_source = '../yolov9/runs/detect/drug2k/labels'
ls_labels = os.listdir(labels_source)
ls_labels.sort()

# %%
len(ls_labels)
# Out:
# 4731

# %%
ls_labels[-1]
# Out:
# 'classes.txt'

# %%
ls_labels.remove('classes.txt')

# %%
len(ls_labels)
# Out:
# 4730

# %%
ls_labels

# %%
path
# Out:
# '../yolov9/runs/detect/drug2k/labels/RXBASE-120_00002-3239-30_NLMIMAGE10_3F1E1F80.txt'

# %%
# ทดสอบเปลี่ยน class ในไฟล์ labels
ls_txt = []
a = ls_labels[0]
path = os.path.join(labels_source,a).replace('\\','/')
with open(path) as txt:
    txt = txt.read().splitlines()
    # with open('/content/drive/MyDrive/datasets/drug_c3pi/4train/pseudo_lables/'+a, 'w') as dst_file:
    #     for line in txt:
    #         cl, x, y, w, h = [i for i in line.split(' ')]
    #         dst_file.writelines(' '.join(['abc', x, y, w, h])+'\n')
    for line in txt:
        cl, x, y, w, h = [i for i in line.split(' ')]
        ls_txt.append([' '.join([a, cl, x, y, w, h])])


ls_txt
# Out:
# [['RXNAV-1024_51293-0611-01_RXNAVIMAGE10_1B468D84.txt 1240 0.762207 0.401786 0.452148 0.513393'],
#  ['RXNAV-1024_51293-0611-01_RXNAVIMAGE10_1B468D84.txt 1240 0.274902 0.402902 0.454102 0.515625']]

# %%
# ทดสอบเปลี่ยน class ในไฟล์ labels ไล่ทีละไฟล์
ls_txt = []
for a in tqdm(ls_labels):
    path = os.path.join(labels_source,a).replace('\\','/')
    with open(path) as txt:
        txt = txt.read().splitlines()
        # with open('/content/drive/MyDrive/datasets/drug_c3pi/4train/pseudo_lables/'+a, 'w') as dst_file:
        #     for line in txt:
        #         cl, x, y, w, h = [i for i in line.split(' ')]
        #         dst_file.writelines(' '.join(['abc', x, y, w, h])+'\n')
        for line in txt:
            cl, x, y, w, h = [i for i in line.split(' ')]
            ls_txt.append([a, cl, x, y, w, h])


ls_txt
# Out:
#   0%|          | 0/4730 [00:00<?, ?it/s]
# [['RXBASE-120_00002-3239-30_NLMIMAGE10_3F1E1F80.txt',
#   '1535',
#   '0.5125',
#   '0.713542',
#   '0.741667',
#   '0.427083'],
#  ['RXBASE-120_00002-3239-30_NLMIMAGE10_3F1E1F80.txt',
#   '1535',
#   '0.5125',
#   '0.239583',
#   '0.741667',
#   '0.416667'],
#  ['RXBASE-120_00002-3270-30_NLMIMAGE10_A91354EA.txt',
#   '1637',
#   '0.5125',
#   '0.713542',
#   '0.741667',
#   '0.427083'],
#  ['RXBASE-120_00002-3270-30_NLMIMAGE10_A91354EA.txt',
#   '1637',
#   '0.4875',
#   '0.229167',
#   '0.741667',
#   '0.416667'],
#  ['RXBASE-120_00002-4772-90_NLMIMAGE10_8C16C656.txt',
#   '1812',
#   '0.2625',
#   '0.46875',
#   '0.491667',
#   '0.604167'],
#  ['RXBASE-120_00002-4772-90_NLMIMAGE10_8C16C656.txt',
#   '1812',
#   '0.766667',
#   '0.46875',
#   '0.466667',
#   '0.604167'],
#  ['RXBASE-120_00002-5123-30_NLMIMAGE10_E848F457.txt',
#   '1820',
#   '0.516667',
#   '0.708333',
#   '0.733333',
#   '0.4375'],
# ...

# %% [markdown]
# # Make ls_txt to be dataframe to merge with image_group.csv

# %%
# Note quantity of images in val are fewer than inferenced to txt

# %%
import pandas as pd

# %%
df_file = pd.DataFrame(ls_txt, columns = ['file', 'cl', 'x', 'y','w', 'h'])

# %%
df_file
# Out:
#                                                    file    cl         x  \
# 0      RXBASE-120_00002-3239-30_NLMIMAGE10_3F1E1F80.txt  1535    0.5125
# 1      RXBASE-120_00002-3239-30_NLMIMAGE10_3F1E1F80.txt  1535    0.5125
# 2      RXBASE-120_00002-3270-30_NLMIMAGE10_A91354EA.txt  1637    0.5125
# 3      RXBASE-120_00002-3270-30_NLMIMAGE10_A91354EA.txt  1637    0.4875
# 4      RXBASE-120_00002-4772-90_NLMIMAGE10_8C16C656.txt  1812    0.2625
# ...                                                 ...   ...       ...
# 9836  RXNAV-ORIGINAL_69543-0107-10_RXNAVIMAGE10_934D...  1609  0.274902
# 9837  RXNAV-ORIGINAL_75826-0114-10_RXNAVIMAGE10_4F50...  1240  0.761719
# 9838  RXNAV-ORIGINAL_75826-0114-10_RXNAVIMAGE10_4F50...  1240  0.274902
# 9839  RXNAV-ORIGINAL_76439-0309-10_RXNAVIMAGE10_333B...   939  0.763184
# 9840  RXNAV-ORIGINAL_76439-0309-10_RXNAVIMAGE10_333B...   939  0.276367
#
#              y         w         h
# 0     0.713542  0.741667  0.427083
# ...

# %% [markdown]
# # Merge val(ground truth) with detect

# %%
df_merge = pd.merge(df_val, df_file, left_on='a', right_on='file', how='left')

# %%
df_merge
# Out:
#                                                       a  cl_x       x_x  \
# 0      RXBASE-120_00002-3239-30_NLMIMAGE10_3F1E1F80.txt  1535  0.516667
# 1      RXBASE-120_00002-3239-30_NLMIMAGE10_3F1E1F80.txt  1535  0.516667
# 2      RXBASE-120_00002-3239-30_NLMIMAGE10_3F1E1F80.txt  1535  0.516667
# 3      RXBASE-120_00002-3239-30_NLMIMAGE10_3F1E1F80.txt  1535  0.516667
# 4      RXBASE-120_00002-3270-30_NLMIMAGE10_A91354EA.txt  1637    0.5125
# ...                                                 ...   ...       ...
# 19717  RXBASE-600_68462-0720-84_NLMIMAGE10_F44FFA2F.txt  2064  0.761667
# 19718  RXBASE-600_68682-0409-10_NLMIMAGE10_6D39B6CD.txt   533  0.520833
# 19719  RXBASE-600_68682-0409-10_NLMIMAGE10_6D39B6CD.txt   533  0.520833
# 19720  RXBASE-600_68682-0409-10_NLMIMAGE10_6D39B6CD.txt   533    0.5225
# 19721  RXBASE-600_68682-0409-10_NLMIMAGE10_6D39B6CD.txt   533    0.5225
#
#             y_x       w_x       h_x  \
# 0      0.234375  0.966667  0.427083
# ...

# %%
pd.merge(df_val.iloc[:2],df_file, left_on=['a','cl'],right_on=['file','cl'],how='left')
# Out:
#                                                   a    cl       x_x       y_x  \
# 0  RXBASE-120_00002-3239-30_NLMIMAGE10_3F1E1F80.txt  1535  0.516667  0.234375
# 1  RXBASE-120_00002-3239-30_NLMIMAGE10_3F1E1F80.txt  1535  0.516667  0.234375
# 2  RXBASE-120_00002-3239-30_NLMIMAGE10_3F1E1F80.txt  1535  0.516667  0.713542
# 3  RXBASE-120_00002-3239-30_NLMIMAGE10_3F1E1F80.txt  1535  0.516667  0.713542
#
#         w_x       h_x                                              file  \
# 0  0.966667  0.427083  RXBASE-120_00002-3239-30_NLMIMAGE10_3F1E1F80.txt
# 1  0.966667  0.427083  RXBASE-120_00002-3239-30_NLMIMAGE10_3F1E1F80.txt
# 2  0.966667  0.427083  RXBASE-120_00002-3239-30_NLMIMAGE10_3F1E1F80.txt
# 3  0.966667  0.427083  RXBASE-120_00002-3239-30_NLMIMAGE10_3F1E1F80.txt
#
#       x_y       y_y       w_y       h_y
# 0  0.5125  0.713542  0.741667  0.427083
# 1  0.5125  0.239583  0.741667  0.416667
# 2  0.5125  0.713542  0.741667  0.427083
# 3  0.5125  0.239583  0.741667  0.416667

# %%
df_val[:4]
# Out:
#                                                   a    cl         x         y  \
# 0  RXBASE-120_00002-3239-30_NLMIMAGE10_3F1E1F80.txt  1535  0.516667  0.234375
# 1  RXBASE-120_00002-3239-30_NLMIMAGE10_3F1E1F80.txt  1535  0.516667  0.713542
# 2  RXBASE-120_00002-3270-30_NLMIMAGE10_A91354EA.txt  1637    0.5125  0.234375
# 3  RXBASE-120_00002-3270-30_NLMIMAGE10_A91354EA.txt  1637    0.5125  0.713542
#
#           w         h
# 0  0.966667  0.427083
# 1  0.966667  0.427083
# 2     0.975  0.427083
# 3     0.975  0.427083

# %%
df_file[:4]
# Out:
#                                                file    cl       x         y  \
# 0  RXBASE-120_00002-3239-30_NLMIMAGE10_3F1E1F80.txt  1535  0.5125  0.713542
# 1  RXBASE-120_00002-3239-30_NLMIMAGE10_3F1E1F80.txt  1535  0.5125  0.239583
# 2  RXBASE-120_00002-3270-30_NLMIMAGE10_A91354EA.txt  1637  0.5125  0.713542
# 3  RXBASE-120_00002-3270-30_NLMIMAGE10_A91354EA.txt  1637  0.4875  0.229167
#
#           w         h
# 0  0.741667  0.427083
# 1  0.741667  0.416667
# 2  0.741667  0.427083
# 3  0.741667  0.416667

# %%
df_merge[:4].drop_duplicates()
# Out:
#                                                   a  cl_x       x_x       y_x  \
# 0  RXBASE-120_00002-3239-30_NLMIMAGE10_3F1E1F80.txt  1535  0.516667  0.234375
# 1  RXBASE-120_00002-3239-30_NLMIMAGE10_3F1E1F80.txt  1535  0.516667  0.234375
# 2  RXBASE-120_00002-3239-30_NLMIMAGE10_3F1E1F80.txt  1535  0.516667  0.713542
# 3  RXBASE-120_00002-3239-30_NLMIMAGE10_3F1E1F80.txt  1535  0.516667  0.713542
#
#         w_x       h_x                                              file  cl_y  \
# 0  0.966667  0.427083  RXBASE-120_00002-3239-30_NLMIMAGE10_3F1E1F80.txt  1535
# 1  0.966667  0.427083  RXBASE-120_00002-3239-30_NLMIMAGE10_3F1E1F80.txt  1535
# 2  0.966667  0.427083  RXBASE-120_00002-3239-30_NLMIMAGE10_3F1E1F80.txt  1535
# 3  0.966667  0.427083  RXBASE-120_00002-3239-30_NLMIMAGE10_3F1E1F80.txt  1535
#
#       x_y       y_y       w_y       h_y
# 0  0.5125  0.713542  0.741667  0.427083
# 1  0.5125  0.239583  0.741667  0.416667
# 2  0.5125  0.713542  0.741667  0.427083
# ...

# %%
df_merge[df_merge.cl_x=='181']
# Out:
#                                                        a cl_x       x_x  \
# 10786  RXBASE-ORIGINAL_00173-0790-01_NLMIMAGE10_D7196...  181  0.519531
# 10787  RXBASE-ORIGINAL_00173-0790-01_NLMIMAGE10_D7196...  181  0.519531
# 10788  RXBASE-ORIGINAL_00173-0790-01_NLMIMAGE10_D7196...  181  0.520996
# 10789  RXBASE-ORIGINAL_00173-0790-01_NLMIMAGE10_D7196...  181  0.520996
# 11114   RXBASE-300_00173-0790-01_NLMIMAGE10_D7196BFB.txt  181      0.52
# 11115   RXBASE-300_00173-0790-01_NLMIMAGE10_D7196BFB.txt  181      0.52
# 11116   RXBASE-300_00173-0790-01_NLMIMAGE10_D7196BFB.txt  181  0.521667
# 11117   RXBASE-300_00173-0790-01_NLMIMAGE10_D7196BFB.txt  181  0.521667
#
#             y_x       w_x       h_x  \
# 10786  0.708984  0.884766  0.417969
# 10787  0.708984  0.884766  0.417969
# 10788  0.235026  0.889648  0.423177
# 10789  0.235026  0.889648  0.423177
# 11114  0.708889  0.886667  0.422222
# 11115  0.708889  0.886667  0.422222
# 11116  0.233333      0.89  0.431111
# ...

# %%
df_diff = df_merge[df_merge.cl_x != df_merge.cl_y]
df_diff
# Out:
#                                                        a  cl_x       x_x  \
# 24      RXBASE-120_00006-0227-61_NLMIMAGE10_A11DD0FE.txt  1846  0.520833
# 27      RXBASE-120_00006-0227-61_NLMIMAGE10_A11DD0FE.txt  1846  0.520833
# 58      RXBASE-800_63459-0504-30_NLMIMAGE10_8841C43E.txt     5  0.520000
# 59      RXBASE-800_63459-0504-30_NLMIMAGE10_8841C43E.txt     5  0.517500
# 180    RXNAV-120_00093-2056-06_RXNAVIMAGE10_D935EC8F.txt  1941  0.279167
# ...                                                  ...   ...       ...
# 19656   RXBASE-800_50419-0409-01_NLMIMAGE10_AC19560A.txt  2086    0.7625
# 19666   RXBASE-800_50458-0647-65_NLMIMAGE10_561E2B21.txt  1945      0.52
# 19669   RXBASE-800_50458-0647-65_NLMIMAGE10_561E2B21.txt  1945   0.52125
# 19709   RXBASE-600_68462-0331-90_NLMIMAGE10_F43E7A43.txt  1269    0.2775
# 19712   RXBASE-600_68462-0331-90_NLMIMAGE10_F43E7A43.txt  1269  0.764167
#
#             y_x       w_x       h_x  \
# 24     0.234375     0.625  0.427083
# ...

# %%
df_diff['a'].value_counts()
# Out:
# a
# RXNAV-ORIGINAL_24090-0497-84_RXNAVIMAGE10_0E510738.txt    8
# RXNAV-ORIGINAL_00025-1520-31_RXNAVIMAGE10_5B39ADCD.txt    6
# RXBASE-800_00555-9028-58_NLMIMAGE10_682FB44D.txt          6
# RXNAV-800_00603-7610-01_RXNAVIMAGE10_2B4B15F8.txt         6
# RXBASE-600_00555-9020-58_NLMIMAGE10_4B36A5F5.txt          6
#                                                          ..
# RXNAV-800_33342-0121-10_RXNAVIMAGE10_2547928C.txt         2
# RXNAV-ORIGINAL_00173-0755-00_RXNAVIMAGE10_BC15DE0E.txt    2
# RXNAV-1024_00228-2577-50_RXNAVIMAGE10_650532A9.txt        2
# RXBASE-ORIGINAL_00555-9028-58_NLMIMAGE10_642FB23D.txt     2
# RXBASE-600_68462-0331-90_NLMIMAGE10_F43E7A43.txt          2
# Name: count, Length: 429, dtype: int64

# %%
df_merge.to_csv('detect_table.csv')

# %%
df_diff.to_csv('error_detect.csv')

# %% [markdown]
# # Start from detect_table (df_merge)

# %%
import pandas as pd
df_merge = pd.read_csv('detect_table.csv')

# %%
df_merge[df_merge.cl_y == 1363]
# Out:
#        Unnamed: 0                                                  a  cl_x  \
# 24             24   RXBASE-120_00006-0227-61_NLMIMAGE10_A11DD0FE.txt  1846
# 27             27   RXBASE-120_00006-0227-61_NLMIMAGE10_A11DD0FE.txt  1846
# 610           610  RXNAV-800_24658-0213-90_RXNAVIMAGE10_853342CA.txt  1363
# 611           611  RXNAV-800_24658-0213-90_RXNAVIMAGE10_853342CA.txt  1363
# 612           612  RXNAV-800_24658-0213-90_RXNAVIMAGE10_853342CA.txt  1363
# 613           613  RXNAV-800_24658-0213-90_RXNAVIMAGE10_853342CA.txt  1363
# 5294         5294  RXBASE-ORIGINAL_16729-0006-17_NLMIMAGE10_5812A...  1363
# 5295         5295  RXBASE-ORIGINAL_16729-0006-17_NLMIMAGE10_5812A...  1363
# 5296         5296  RXBASE-ORIGINAL_16729-0006-17_NLMIMAGE10_5812A...  1363
# 5297         5297  RXBASE-ORIGINAL_16729-0006-17_NLMIMAGE10_5812A...  1363
# 6506         6506  RXNAV-1024_00006-0227-61_RXNAVIMAGE10_A11DD0FE...  1846
# ...

# %%
cl1363 = df_merge[df_merge.cl_y == 1363]['a'].unique()

# %%
rm_mkdir('1363')

# %%
from tqdm.notebook import tqdm
for pic in tqdm(cl1363):
    shutil.copy(src=os.path.join('../yolov9/runs/detect/drug2k/', pic[:-3]+'jpg'), dst=os.path.join('1363', pic[:-3]+'jpg'))
# Out:
#   0%|          | 0/9 [00:00<?, ?it/s]

# %%
cl1846 = df_merge[df_merge.cl_y == 1846]['a'].unique()
rm_mkdir('1846')
from tqdm.notebook import tqdm
for pic in tqdm(cl1846):
    shutil.copy(src=os.path.join('../yolov9/runs/detect/drug2k/', pic[:-3]+'jpg'), dst=os.path.join('1846', pic[:-3]+'jpg'))
# Out:
#   0%|          | 0/3 [00:00<?, ?it/s]

# %%
def groundtruth_check(cl_truth):
    cls1  = df_merge[df_merge.cl_x == int(cl_truth)]['a'].unique()
    rm_mkdir(cl_truth)
    from tqdm.notebook import tqdm
    for pic in tqdm(cls1):
        shutil.copy(src=os.path.join('../yolov9/runs/detect/drug2k/', pic[:-3]+'jpg'), dst=os.path.join(cl_truth, pic[:-3]+'jpg'))

# %%
groundtruth_check('1363')
# Out:
#   0%|          | 0/6 [00:00<?, ?it/s]

# %%
groundtruth_check('1846')
# Out:
#   0%|          | 0/3 [00:00<?, ?it/s]

# %% [markdown]
# # Export diff images

# %%
import shutil
if os.path.exists('diff_img'):
    shutil.rmtree('diff_img')
    os.makedirs('diff_img')
else:
    os.makedirs('diff_img')

# %%
for pic in tqdm(df_diff['a'].unique()):
    shutil.copy(os.path.join('../yolov9/runs/detect/drug2k/', pic[:-3]+'jpg'), os.path.join('diff_img', pic[:-3]+'jpg'))
# Out:
#   0%|          | 0/429 [00:00<?, ?it/s]

# %%
len(df_merge.a.unique())
# Out:
# 4750

# %%
print(len(df_file), len(df_val))
# Out:
# 9841 9500

# %%
9841+9500
# Out:
# 19341

# %%
df_merge.drop_duplicates(inplace=True)

# %%
len(df_merge)
# Out:
# 19722

# %%
df_val.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9500 entries, 0 to 9499
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   a       9500 non-null   object
#  1   cl      9500 non-null   object
#  2   x       9500 non-null   object
#  3   y       9500 non-null   object
#  4   w       9500 non-null   object
#  5   h       9500 non-null   object
# dtypes: object(6)
# memory usage: 445.4+ KB

# %%
df_file.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9841 entries, 0 to 9840
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   file    9841 non-null   object
#  1   cl      9841 non-null   object
#  2   x       9841 non-null   object
#  3   y       9841 non-null   object
#  4   w       9841 non-null   object
#  5   h       9841 non-null   object
# dtypes: object(6)
# memory usage: 461.4+ KB

# %% [markdown]
# # For merge with image_roup.csv

# %%
df_file['file'].apply(lambda v: v[:-3]+'jpg')
# Out:
# 0        RXBASE-120_00002-3239-30_NLMIMAGE10_3F1E1F80.jpg
# 1        RXBASE-120_00002-3239-30_NLMIMAGE10_3F1E1F80.jpg
# 2        RXBASE-120_00002-3270-30_NLMIMAGE10_A91354EA.jpg
# 3        RXBASE-120_00002-3270-30_NLMIMAGE10_A91354EA.jpg
# 4        RXBASE-120_00002-4772-90_NLMIMAGE10_8C16C656.jpg
#                               ...
# 9455    RXNAV-ORIGINAL_69543-0107-10_RXNAVIMAGE10_934D...
# 9456    RXNAV-ORIGINAL_75826-0114-10_RXNAVIMAGE10_4F50...
# 9457    RXNAV-ORIGINAL_75826-0114-10_RXNAVIMAGE10_4F50...
# 9458    RXNAV-ORIGINAL_76439-0309-10_RXNAVIMAGE10_333B...
# 9459    RXNAV-ORIGINAL_76439-0309-10_RXNAVIMAGE10_333B...
# Name: file, Length: 9460, dtype: object

# %%
df_file['im_file2'] = df_file['file'].apply(lambda v: v[:-3]+'jpg')
df_file
# Out:
#                                                    file    cl         x  \
# 0      RXBASE-120_00002-3239-30_NLMIMAGE10_3F1E1F80.txt  1535  0.516667
# 1      RXBASE-120_00002-3239-30_NLMIMAGE10_3F1E1F80.txt  1535  0.516667
# 2      RXBASE-120_00002-3270-30_NLMIMAGE10_A91354EA.txt  1637    0.5125
# 3      RXBASE-120_00002-3270-30_NLMIMAGE10_A91354EA.txt  1637    0.5125
# 4      RXBASE-120_00002-4772-90_NLMIMAGE10_8C16C656.txt  1812    0.2625
# ...                                                 ...   ...       ...
# 9455  RXNAV-ORIGINAL_69543-0107-10_RXNAVIMAGE10_934D...  1609  0.763184
# 9456  RXNAV-ORIGINAL_75826-0114-10_RXNAVIMAGE10_4F50...  1240  0.275879
# 9457  RXNAV-ORIGINAL_75826-0114-10_RXNAVIMAGE10_4F50...  1240  0.763184
# 9458  RXNAV-ORIGINAL_76439-0309-10_RXNAVIMAGE10_333B...   939  0.763184
# 9459  RXNAV-ORIGINAL_76439-0309-10_RXNAVIMAGE10_333B...   939  0.276367
#
#              y         w         h  \
# 0     0.234375  0.966667  0.427083
# ...

# %%
df_file['im_file2'].value_counts()
# Out:
# im_file2
# RXBASE-120_00002-3239-30_NLMIMAGE10_3F1E1F80.jpg          2
# RXNAV-300_00378-0257-10_RXNAVIMAGE10_7407BA5D.jpg         2
# RXNAV-300_00378-2590-77_RXNAVIMAGE10_7F493FB9.jpg         2
# RXNAV-300_00378-2537-01_RXNAVIMAGE10_04268244.jpg         2
# RXNAV-300_00378-2302-01_RXNAVIMAGE10_214590FC.jpg         2
#                                                          ..
# RXBASE-800_49702-0214-18_NLMIMAGE10_74193A49.jpg          2
# RXBASE-800_47335-0539-81_NLMIMAGE10_703C3801.jpg          2
# RXBASE-800_45963-0142-30_NLMIMAGE10_CB48E587.jpg          2
# RXBASE-800_45802-0594-65_NLMIMAGE10_AC125672.jpg          2
# RXNAV-ORIGINAL_76439-0309-10_RXNAVIMAGE10_333B19B8.jpg    2
# Name: count, Length: 4730, dtype: int64

# %%
df_imgr = pd.read_csv('image_group.csv')
df_imgr
# Out:
#                                              name       resolution  \
# 0      Loperamide Hydrochloride 2 MG Oral Capsule        RXNAV 120
# 1                  Minocycline 50 MG Oral Capsule        RXNAV 120
# 2                Nortriptyline 10 MG Oral Capsule        RXNAV 120
# 3                Nortriptyline 25 MG Oral Capsule        RXNAV 120
# 4                Nortriptyline 50 MG Oral Capsule        RXNAV 120
# ...                                           ...              ...
# 47497        Enalapril Maleate 2.5 MG Oral Tablet  RXBASE ORIGINAL
# 47498                  quinapril 5 MG Oral Tablet  RXBASE ORIGINAL
# 47499         trospium chloride 20 MG Oral Tablet  RXBASE ORIGINAL
# 47500               metaxalone 400 MG Oral Tablet  RXBASE ORIGINAL
# 47501              naratriptan 2.5 MG Oral Tablet  RXBASE ORIGINAL
#
#                                                     path  has_image  \
# 0      image/images/gallery/120/00093-0311-01_RXNAVIM...       True
# ...

# %%
df3 = pd.merge(df_imgr, df_file, left_on='im_file', right_on='im_file2', how='left')

# %%
df3.dropna(inplace=True)

# %%
df3
# Out:
#                                           name       resolution  \
# 3             Nortriptyline 25 MG Oral Capsule        RXNAV 120
# 4             Nortriptyline 25 MG Oral Capsule        RXNAV 120
# 7       Hydroxyzine Pamoate 50 MG Oral Capsule        RXNAV 120
# 8       Hydroxyzine Pamoate 50 MG Oral Capsule        RXNAV 120
# 13     doxycycline hyclate 100 MG Oral Capsule        RXNAV 120
# ...                                        ...              ...
# 52180     Enalapril Maleate 2.5 MG Oral Tablet  RXBASE ORIGINAL
# 52193            Doxycycline 20 MG Oral Tablet  RXBASE ORIGINAL
# 52194            Doxycycline 20 MG Oral Tablet  RXBASE ORIGINAL
# 52223          Griseofulvin 250 MG Oral Tablet  RXBASE ORIGINAL
# 52224          Griseofulvin 250 MG Oral Tablet  RXBASE ORIGINAL
#
#                                                     path  has_image  \
# 3      image/images/gallery/120/00093-0811-01_RXNAVIM...       True
# ...

# %%
df3['cl'] = df3['cl'].astype('int64')

# %%
df3[df3['class'] != df3['cl']]
# Out:
#                                                     name       resolution  \
# 860                     Warfarin Sodium 4 MG Oral Tablet        RXNAV 120
# 861                     Warfarin Sodium 4 MG Oral Tablet        RXNAV 120
# 5612                    Warfarin Sodium 4 MG Oral Tablet       RXBASE 120
# 5613                    Warfarin Sodium 4 MG Oral Tablet       RXBASE 120
# 10868  Amphetamine aspartate 3.125 MG / Amphetamine S...        RXNAV 300
# 10869  Amphetamine aspartate 3.125 MG / Amphetamine S...        RXNAV 300
# 12643                         Doxazosin 4 MG Oral Tablet        RXNAV 300
# 12644                         Doxazosin 4 MG Oral Tablet        RXNAV 300
# 22129                         Doxazosin 4 MG Oral Tablet        RXNAV 600
# 22130                         Doxazosin 4 MG Oral Tablet        RXNAV 600
# 26511  Atropine Sulfate 0.0194 MG / Hyoscyamine Sulfa...       RXBASE 600
# 26512  Atropine Sulfate 0.0194 MG / Hyoscyamine Sulfa...       RXBASE 600
# ...

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9841 entries, 3 to 52605
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        9841 non-null   object
#  1   resolution  9841 non-null   object
#  2   path        9841 non-null   object
#  3   has_image   9841 non-null   bool
#  4   im_file     9841 non-null   object
#  5   class       9841 non-null   int64
#  6   file        9841 non-null   object
#  7   cl          9841 non-null   int64
#  8   x           9841 non-null   object
#  9   y           9841 non-null   object
#  10  w           9841 non-null   object
#  11  h           9841 non-null   object
#  12  im_file2    9841 non-null   object
# dtypes: bool(1), int64(2), object(10)
# memory usage: 1009.1+ KB
